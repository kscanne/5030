# %%
class convertLowerCase():

    def lc(self, text):
        return text.lower()       
    
    def tr(self, text):
        lowercase = ""
        turkish_dict = {'I':'ı', 'İ':'i'}
        for word in text:
            if word == 'I' or word == 'İ':
                lowercase += turkish_dict[word]
            else:
                lowercase += word.lower()
        return lowercase            
    
    
    def el(self, text):  
        lowercase = ""
        if text[-1] == 'Σ':
            lowercase += text[0:-1].lower()+'ς'
        else:
            lowercase += text.lower()
        return lowercase 


    
    
    
    def ga(self, text):
        lowercase = "" 
        checks = 'AEIOU'
        for w in range(0, len(text)-1):
            if text[w] == 't' or text[w] == 'n':
                if text[w+1] in checks:
                    lowercase += text[w] + '-'
                else:
                    lowercase += text[w].lower()
            else:
                lowercase += text[w].lower()
            
        return lowercase + text[-1].lower()    
    
    
    
    def ga_ie(self, text):
        lowercase = "" 
        checks = 'AEIOUÁÉÍÓÚ'
        for w in range(0, len(text)-2):
            if text[w] == 't' or text[w] == 'n':
                if (text[w+1] + text[w+2]) in 'ÃB̃C̃D̃ẼẼF̃G̃H̃ĨJ̃K̃L̃M̃ÕP̃Q̃R̃S̃T̃ŨṼW̃X̃ỸZ̃':   
                    lowercase += text[w]
                else:
                    if text[w+1] in checks:
                        lowercase += text[w] + '-'
                    else:
                        lowercase += text[w].lower()
            else:
                lowercase += text[w].lower()
            
        if text[-2] == 't' or text[-2] == 'n':
            if text[-1] in checks:
                lowercase += text[-2] + '-'
            else:
                lowercase += text[-2].lower()
        else:       
            lowercase += text[-2].lower()        
         
        
        return lowercase + text[-1].lower()

    
    
    
    

def language(txt, lang_code):
    
    lang_code = lang_code
    text = txt 
     
    lang_direct = ['en', 'th', 'en-us', 'zh-hans', 'en-latn', 'en-ie']
    
    if [lang for lang in lang_direct if lang_code in lang]:        
        return obj.lc(text)
    elif lang_code == 'tr':
        return obj.tr(text)
    elif lang_code == 'el':
        return obj.el(text)
    elif lang_code == 'ga':
        return obj.ga(text)
    elif lang_code=='ga-ie': 
        return obj.ga_ie(text)
    else:
        return 'nothing selected in the list'

    
    
    
text_input = input("Enter text: ").strip()
lang_code = input("Enter language code: ").lower().strip()

obj = convertLowerCase()    


lowercase_text = language(text_input, lang_code)






print("Text in lowercase: {}".format(lowercase_text))
# Out:
# Enter text: DFF
# Enter language code: en
# Text in lowercase: dff

# %%
# test case

import pandas as pd



class convertLowerCaseTest():
    
    data = pd.read_csv('tests.tsv', delimiter = '\t')
    test_data = [list(row) for row in data.values]



    for i in test_data:
        text = i[0]
        lang_code = i[1].lower()
    
        print('input: ' + text)
        print('lang: ' + i[1])
    
        lowercase_text = language(text, lang_code)
    
        print("Your scenario: " + lowercase_text)
        print("Actual scenario: " + i[2])
        print('\n')
    
    
objt = convertLowerCaseTest()
# Out:
# input: WORLD
# lang: en-US
# Your scenario: world
# Actual scenario: world
#
#
# input: cAmEl
# lang: en-IE
# Your scenario: camel
# Actual scenario: camel
#
#
# input: ---OK
# lang: en-Latn
# Your scenario: ---ok
# Actual scenario: ---ok
#
#
# input: tAcht
# lang: ga
# Your scenario: t-acht
# Actual scenario: t-acht
#
#
# input: tACHT
# lang: ga
# Your scenario: t-acht
# Actual scenario: t-acht
#
#
# input: TACHT
# lang: ga
# Your scenario: tacht
# Actual scenario: tacht
#
#
# input: nAthair
# lang: ga
# Your scenario: n-athair
# Actual scenario: n-athair
#
#
# input: nATHAIR
# lang: ga
# Your scenario: n-athair
# Actual scenario: n-athair
#
#
# input: NATHAIR
# lang: ga
# Your scenario: nathair
# Actual scenario: nathair
#
#
# input: nÓg
# lang: ga-IE
# Your scenario: n-óg
# Actual scenario: n-óg
#
#
# input: nÕg
# lang: ga-IE
# Your scenario: nõg
# Actual scenario: nõg
#
#
# input: nÕg
# lang: ga-IE
# Your scenario: nõg
# Actual scenario: nõg
#
#
# input: KASIM
# lang: tr
# Your scenario: kasım
# Actual scenario: kasım
#
#
# input: KASIM
# lang: en
# Your scenario: kasim
# Actual scenario: kasim
#
#
# input: ΠΌΛΗΣ
# lang: el
# Your scenario: πόλης
# Actual scenario: πόλης
#
#
# input: 官话
# lang: zh-Hans
# Your scenario: 官话
# Actual scenario: 官话
#
#
# input: ภาษาไทย
# lang: th
# Your scenario: ภาษาไทย
# Actual scenario: ภาษาไทย
